# %% [markdown]
# ![image info](https://upload.wikimedia.org/wikipedia/commons/8/8c/Cristiano_Ronaldo_2018.jpg)

# %%
def cr7():    
    print('o '*11)
    for i in range(0,11,1):
        print('          o')
    print('o '*11)
    print()
    print()
    for i in range(0,12,1):
        print('o')
    print('o '*11)
    print()
    print()
    for i in range(0,12,1):
        print('o                   o')
    print('o '*11)
    print()
    print()
    for i in range (0,14,1):
        if i==0 or i==13:
            print('o '*11)
        else:
            print('o')
    print()
    print()
    for i in range (0,14,1):
            if i==0 or i==6:
                print('o '*9)
            elif i<=5:
                print('o               o')
            else:
                print('o',' '*(i-5),'o')
    print()
    print()
    for i in range (0,14,1):
        if i==0:
            print('o o o o o o o o')
        else:
            print(' '*(14-i),'o')
cr7()
# Out:
# o o o o o o o o o o o
#           o
#           o
#           o
#           o
#           o
#           o
#           o
#           o
#           o
#           o
#           o
# o o o o o o o o o o o
#
#
# o
# o
# o
# o
# o
# o
# o
# o
# o
# o
# o
# o
# o o o o o o o o o o o
#
#
# o                   o
# o                   o
# o                   o
# o                   o
# o                   o
# o                   o
# o                   o
# o                   o
# o                   o
# o                   o
# o                   o
# o                   o
# o o o o o o o o o o o
#
#
# o o o o o o o o o o o
# o
# o
# o
# o
# o
# o
# o
# o
# o
# o
# o
# o
# o o o o o o o o o o o
#
#
# o o o o o o o o o
# o               o
# o               o
# o               o
# o               o
# o               o
# o o o o o o o o o
# o    o
# o     o
# o      o
# o       o
# o        o
# o         o
# o          o
#
#
# o o o o o o o o
#               o
#              o
#             o
#            o
#           o
#          o
#         o
#        o
#       o
#      o
#     o
#    o
#   o
