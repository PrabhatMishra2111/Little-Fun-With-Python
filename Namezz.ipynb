# %%
def Sahil():
    for i in range(1,12):
        if i==1:
            print('* '*7,' '*14,'*',' '*14,'* ',' '*7,'* ',' '*5,'* '*7,' '*5,'*')
        elif i==2:
            print('* ',' '*25,'* '*2,' '*12,'* ',' '*7,'* ',' '*11,'* ',' '*11,'*')
        elif i<=5:
            print('* ',' '*(27-i),'* ',' '*(2*i-6),'* ',' '*(14-i),'* ',' '*7,'* ',' '*11,'* ',' '*11,'* ')
        elif i==6:
            print('* '*7,' '*9,'* '*6,' '*8,'* '*6,' '*12,'* ',' '*11,'*')
        elif i<=10:
            print(' '*10,' *',' '*(16-i),'* ',' '*(2*i-6),'* ',' '*(14-i),'* ',' '*7,'* ',' '*11,'* ',' '*11,'* ')
        else:
            print('* '*7,' '*(15-i),'* ',' '*(2*i-6),'* ',' '*(14-i),'* ',' '*7,'* ',' '*5,'* '*7,' '*5,'* '*7)

def Harsh():
    for i in range(1,12):
        if i==1:
            print('* ',' '*6,'* ',' '*14,'* ',' '*14,'* '*6,' '*7,' '*3,'* '*6,' '*5,'* ',' '*6,'* ')
        elif i==2:
            print('* ',' '*6,'* ',' '*13,'* '*2,' '*13,'* ',' '*6,'* ',' '*11,'* ',' '*15,'* ',' '*6,'* ')
        elif i<=5:
            print('* ',' '*6,'* ',' '*(15-i),'* ',' '*(2*i-6),'* ',' '*(15-i),'* ',' '*6,'* ',' '*11,'* ',' '*15,'* ',' '*6,'* ')
        elif i==6:
            print('* '*6,' '*9,'* '*6,' '*9,'* '*6,' '*11,'* '*6,' '*5,'* '*6)
        elif i<11:
            print('* ',' '*6,'* ',' '*(15-i),'*',' '*(2*i-5),'* ',' '*(15-i),'* ',' '*(i-6),'* ',' '*(33-i),'* ',' '*5,'* ',' '*6,'*')
        else:
            print('* ',' '*6,'* ',' '*4,'* ',' '*16,'* ',' '*4,'* ',' '*6,'* ',' '*11,'* '*6,' '*5,'* ',' '*6,'* ')

def Akshay():
    for i in range(1,12):
        if i==1:
            print(' '*10,'* ',' '*10,'* ',' '*4,'* ',' '*5,'* '*5,' '*5,'* ',' '*5,'* ',' '*10,'* ',' '*10,'* ',' '*8,'* ')
        elif i==2:
            print(' '*9,'* '*2,' '*9,'* ',' '*3,'* ',' '*6,'* ',' '*13,'* ',' '*5,'* ',' '*9,'* '*2,' '*10,'* ',' '*6,'* ')
        elif i<=5:
            print(' '*(11-i),'* ',' '*(2*i-6),'* ',' '*(11-i),'* ',' '*(5-i),'* ',' '*(i+4),'* ',' '*13,'* ',' '*5,'* ',' '*(11-i),'* ',' '*(2*i-6),'* ',' '*10,'* ',' '*(10-2*i),'* ')
        elif i==6:
            print(' '*5,'* '*6,' '*5,'* ','* ',' '*10,'* '*5,' '*5,'* '*5,' '*6,'* '*6,' '*11,'* ')
        elif i<=10:
            print(' '*(11-i),'*',' '*(2*i-5),'* ',' '*(11-i),'* ',' '*(i-7),'* ',' '*(24-i),'* ',' '*5,'* ',' '*5,'* ',' '*(11-i),'* ',' '*(2*i-6),'* ',' '*(17-i),'*' )
        else:
            print('','* ',' '*16,'* ','','* ',' '*4,'* ',' '*5,'* '*5,' '*5,'* ',' '*5,'* ','','* ',' '*16,'* ',' '*6,'* ')
            
Harsh()
print('\n\n\n\n\n')
Sahil()
print('\n\n\n\n\n')
Akshay()
# Out:
# *         *                 *                 * * * * * *              * * * * * *        *         *
# *         *                * *                *         *              *                  *         *
# *         *               *   *               *         *              *                  *         *
# *         *              *     *              *         *              *                  *         *
# *         *             *       *             *         *              *                  *         *
# * * * * * *            * * * * * *            * * * * * *              * * * * * *        * * * * * *
# *         *           *           *           *    *                             *        *         *
# *         *          *             *          *     *                            *        *         *
# *         *         *               *         *      *                           *        *         *
# ...
